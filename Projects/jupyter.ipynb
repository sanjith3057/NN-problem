# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjith3057/NN-problem/blob/main/Projects/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project ::: 01 : MLOps + Drift Detection Pipeline

# %%
# Cell 1: Mount Drive + Create Project
from google.colab import drive
drive.mount('/content/drive')

# !mkdir -p /content/drive/MyDrive/DriftShield-MLOps
# %cd /content/drive/MyDrive/DriftShield-MLOps

# Initialize git (run once)
# !git config --global user.email "sanjith3057e@gmail.com"
# !git config --global user.name "Sanji3057e"
# !git init
# !git remote add origin https://github.com/yourusername/DriftShield-MLOps.git  # CHANGE THIS
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/DriftShield-MLOps
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/DriftShield-MLOps/.git/

# %%
# CELL A – FIX GIT BRANCH + REMOTE (RUN THIS FIRST)
# %cd /content/drive/MyDrive/DriftShield-MLOps

# Rename master → main (2025 standard)
# !git branch -M main

# ADD YOUR REAL GITHUB REPO (create it on GitHub first → empty repo, no README)
# !git remote set-url origin https://github.com/Sanji3057e/DriftShield-MLOps.git
# ↑↑↑↑ CHANGE ONLY IF YOUR USERNAME IS DIFFERENT

# !git pull origin main --allow-unrelated-histories || echo "No problem
# Out:
# /content/drive/MyDrive/DriftShield-MLOps
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
